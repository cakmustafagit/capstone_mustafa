# %% [markdown]
# # Capstone Webscrapping using BeautifulSoup
#
# This notebook contains guidances & tasks on the data processing for the application
#
# ## background
#
# Sangat tertarik untuk eksplorasi penelitian bidang NLP dan hal itu akan banyak membutuhkan scraping data dari berbagai sumber data secara online. Oleh karena itu pada capstone project ini saya menentukan pilihan WEB SCRAPING menggunakan BeautifulShoup.
#
# ## Requesting the Data and Creating a BeautifulSoup
#
# Let's begin with requesting the web from the site with `get` method.

# %%
import requests

url_get = requests.get('https://www.kalibrr.id/job-board/te/data/1')

# %% [markdown]
# To visualize what exactly you get from the `request.get`, we can use .content so ee what we exactly get, in here i slice it so it won't make our screen full of the html we get from the page. You can delete the slicing if you want to see what we fully get.

# %%
url_get.content[1:500]
# Out:
# b'!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><script type="application/ld+json">{\n    "@context": "https://schema.org",\n    "@type": "WebSite",\n    "url": "https://www.kalibrr.com",\n    "potentialAction": [\n      {\n        "@type": "SearchAction",\n        "target": "https://www.kalibrr.com/job-board/te/={search_term_string}",\n        "query-input": "required name=search_term_string"\n      }\n     ]\n  }</script><meta property="og:i'

# %% [markdown]
# As we can see we get a very unstructured and complex html, which actually contains the codes needed to show the webpages on your web browser. But we as human still confused what and where we can use that piece of code, so here where we use the beautifulsoup. Beautiful soup class will result a beautifulsoup object. Beautiful Soup transforms a complex HTML document into a complex tree of Python objects.
#
# Let's make Beautiful soup object and feel free to explore the object here.

# %%
from bs4 import BeautifulSoup 

soup = BeautifulSoup(url_get.content,"html.parser")

# %% [markdown]
# ## Finding the right key to scrap the data & Extracting the right information

# %% [markdown]
# Find the key and put the key into the `.find()` Put all the exploring the right key at this cell. (please change this markdown with your explanation)

# %%
posisi = soup.find('a',attrs={'class':'k-text-primary-color'})
print(table.prettify()[1:1000])
# Out:
# a class="k-text-primary-color" href="/c/pt-berlian-sistem-informasi/jobs/204136/data-analyst-2" itemprop="name">
#  Data Analyst
# </a>

# %%
posisi = soup.find_all('a',attrs={'class':'k-text-primary-color'})
posisi
# Out:
# [<a class="k-text-primary-color" href="/c/pt-berlian-sistem-informasi/jobs/204136/data-analyst-2" itemprop="name">Data Analyst</a>,
#  <a class="k-text-primary-color" href="/c/vlink-inc/jobs/210140/data-engineer" itemprop="name">Data Engineer</a>,
#  <a class="k-text-primary-color" href="/c/pgi-data/jobs/215150/it-data-center-monitoring" itemprop="name">IT Data Center  Monitoring</a>,
#  <a class="k-text-primary-color" href="/c/pt-indocyber-global-technology/jobs/226730/big-data-engineer-dm" itemprop="name">Big Data Engineer (DM)</a>,
#  <a class="k-text-primary-color" href="/c/pgi-data/jobs/187713/full-stack-developer-reactjs-golang" itemprop="name">Full Stack Developer (ReactJS &amp; Golang)</a>,
#  <a class="k-text-primary-color" href="/c/magna-solusi-indonesia/jobs/212247/data-engineer" itemprop="name">Data Engineer</a>,
#  <a class="k-text-primary-color" href="/c/alam-sutera/jobs/225458/digital-marketing-specialist" itemprop="name">Digital Marketing Specialist</a>,
#  <a class="k-text-primary-color" href="/c/quantyc-ai/jobs/230065/data-engineer" itemprop="name">Data Engineer</a>,
#  <a class="k-text-primary-color" href="/c/pt-berlian-sistem-informasi/jobs/228647/it-asset-management-officer" itemprop="name">IT Asset Management Officer</a>,
#  <a class="k-text-primary-color" href="/c/mobius-digital/jobs/225304/devops-and-data-engineer-2" itemprop="name">DevOps and Data Engineer</a>,
#  <a class="k-text-primary-color" href="/c/astra-financial/jobs/229894/data-engineering-insight-lead-head-of-data" itemprop="name">Data Engineering &amp; Insight Lead (Head of Data)</a>,
#  <a class="k-text-primary-color" href="/c/hana-bank/jobs/223488/data-engineer" itemprop="name">Data Engineer</a>,
#  <a class="k-text-primary-color" href="/c/kalibrr-ph/jobs/222641/client-success-associate-4" itemprop="name">Client Success Associate</a>,
#  <a class="k-text-primary-color" href="/c/algoritma/jobs/227729/sr-business-development-b2b-corporate-sales" itemprop="name">Sr Business Development (B2B Corporate Sales)</a>,
#  <a class="k-text-primary-color" href="/c/pt-asuransi-allianz-life-indonesia/jobs/230362/data-scientist-5" itemprop="name">Data Scientist</a>,
#  <a aria-current="page" aria-label="Page 1 is your current page" class="k-rounded-full k-inline-flex k-items-center k-justify-center k-border-2 k-border-primary-color-200 k-w-12 k-h-12 k-font-medium k-text-grey-700 hover:k-bg-primary-color hover:k-text-white k-bg-primary-color-200 k-border-transparent k-text-primary-color k-font-bold" role="button" tabindex="0">1</a>,
#  <a class="k-text-primary-color k-font-bold k-text-sm md:k-text-base" href="/job-board/te/data/1#">View All</a>,
#  <a class="k-text-primary-color k-font-bold k-text-sm md:k-text-base" href="/job-board/te/data/1#">View All</a>]

# %%
lokasi = soup.find_all('a',attrs={'class':'k-text-subdued k-block'})
lokasi
# Out:
# [<a class="k-text-subdued k-block" href="/job-board/l/East-Jakarta">East Jakarta, Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Jakarta-Selatan">Jakarta Selatan, Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Jakarta">Jakarta, Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/West-Jakarta">West Jakarta, Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Jakarta">Jakarta, Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Jakarta-Selatan">Jakarta Selatan, Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Tangerang-Kota">Tangerang Kota, Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Jakarta-Selatan">Jakarta Selatan, Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/East-Jakarta">East Jakarta, Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Tangerang-Selatan">Tangerang Selatan, Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Central-Jakarta-City">Central Jakarta City, Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Jakarta-Selatan">Jakarta Selatan, Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/South-Jakarta">South Jakarta, Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Jakarta-Selatan">Jakarta Selatan, Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/South-Jakarta">South Jakarta, Indonesia</a>]

# %%
perusahaan = soup.find_all('a',attrs={'class':'k-text-subdued'})
perusahaan
# Out:
# [<a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/pt-berlian-sistem-informasi/jobs"><div><img alt="PT Berlian Sistem Informasi" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="eager" src="https://rec-data.kalibrr.com/www.kalibrr.com/logos/HELY75DFBQLJMNBNXJWB4LJCAZRYW7WPUJLN8CUH-649a6aba.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/pt-berlian-sistem-informasi/jobs">PT Berlian Sistem Informasi</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/East-Jakarta">East Jakarta, Indonesia</a>,
#  <a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/vlink-inc/jobs"><div><img alt="VLink Inc" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="eager" src="https://rec-data.kalibrr.com/www.kalibrr.com/logos/AEGY7VUHFWL7LCE9JD4BALCRKJRR3JLWGTC7R7S9-63047b16.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/vlink-inc/jobs">VLink Inc</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Jakarta-Selatan">Jakarta Selatan, Indonesia</a>,
#  <a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/pgi-data/jobs"><div><img alt="PGI Data" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="eager" src="https://rec-data.kalibrr.com/www.kalibrr.com/logos/Z7AL3F4XGKPLCEW9TFDFDZK33247MQ8J9PSHES26-6080167e.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/pgi-data/jobs">PGI Data</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Jakarta">Jakarta, Indonesia</a>,
#  <a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/pt-indocyber-global-technology/jobs"><div><img alt="PT. Indocyber Global Technology" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="eager" src="https://rec-data.kalibrr.com/logos/7A2NJVVKQWTJLM5DPPVJGSWRGCBCVJJE48BAPJFY-5ad021aa.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/pt-indocyber-global-technology/jobs">PT. Indocyber Global Technology</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/West-Jakarta">West Jakarta, Indonesia</a>,
#  <a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/pgi-data/jobs"><div><img alt="PGI Data" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="lazy" src="https://rec-data.kalibrr.com/www.kalibrr.com/logos/Z7AL3F4XGKPLCEW9TFDFDZK33247MQ8J9PSHES26-6080167e.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/pgi-data/jobs">PGI Data</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Jakarta">Jakarta, Indonesia</a>,
#  <a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/magna-solusi-indonesia/jobs"><div><img alt="Magna Solusi Indonesia" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="lazy" src="https://rec-data.kalibrr.com/www.kalibrr.com/logos/T2NHPYMKBNLMU9Q5Y3FPZYGTQ39FPGU2Y9KM6QZC-62dfa5bb.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/magna-solusi-indonesia/jobs">Magna Solusi Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Jakarta-Selatan">Jakarta Selatan, Indonesia</a>,
#  <a class="k-text-subdued" href="/job-board/sgt/7000000/si/monthly/1"><span>IDR 7,000,000.00</span><span> <!-- -->- <!-- -->IDR 15,000,000.00</span><span>  / <!-- -->month</span></a>,
#  <a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/alam-sutera/jobs"><div><img alt="PT Alam Sutera Realty Tbk" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="lazy" src="https://rec-data.kalibrr.com/www.kalibrr.com/logos/G43AXJ7F92LA9JJMU8F93UL348YYYMXHRV2GJCMD-641820e7.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/alam-sutera/jobs">PT Alam Sutera Realty Tbk</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Tangerang-Kota">Tangerang Kota, Indonesia</a>,
#  <a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/quantyc-ai/jobs"><div><img alt="Quantyc.ai" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="lazy" src="https://rec-data.kalibrr.com/www.kalibrr.com/logos/XVQS285L33W9DWFB3R8PRE3NR82KM26Y3XJZRXJB-64ae39a7.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/quantyc-ai/jobs">Quantyc.ai</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Jakarta-Selatan">Jakarta Selatan, Indonesia</a>,
#  <a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/pt-berlian-sistem-informasi/jobs"><div><img alt="PT Berlian Sistem Informasi" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="lazy" src="https://rec-data.kalibrr.com/www.kalibrr.com/logos/HELY75DFBQLJMNBNXJWB4LJCAZRYW7WPUJLN8CUH-649a6aba.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/pt-berlian-sistem-informasi/jobs">PT Berlian Sistem Informasi</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/East-Jakarta">East Jakarta, Indonesia</a>,
#  <a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/mobius-digital/jobs"><div><img alt="Mobius Digital" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="lazy" src="https://rec-data.kalibrr.com/www.kalibrr.com/logos/JK3LVPAFEXMJNDEHQWVC7XUSMZYT7CMYS3PAN4T8-63fc25b7.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/mobius-digital/jobs">Mobius Digital</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Tangerang-Selatan">Tangerang Selatan, Indonesia</a>,
#  <a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/astra-financial/jobs"><div><img alt="Astra Financial" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="lazy" src="https://rec-data.kalibrr.com/www.kalibrr.com/logos/96ACHKRYFY7ER9FY3D5GTW7CM44HHWEQ4E63PQCP-5ef56e46.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/astra-financial/jobs">Astra Financial</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Central-Jakarta-City">Central Jakarta City, Indonesia</a>,
#  <a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/hana-bank/jobs"><div><img alt="Hana Bank" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="lazy" src="https://rec-data.kalibrr.com/www.kalibrr.com/logos/E872HKANQT5QWTMYQTFWHKKS5ECVL99VUH2TS47S-62c5561f.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/hana-bank/jobs">Hana Bank</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Jakarta-Selatan">Jakarta Selatan, Indonesia</a>,
#  <a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/kalibrr-ph/jobs"><div><img alt="Kalibrr " class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="lazy" src="https://rec-data.kalibrr.com/www.kalibrr.com/logos/JP7NLP256AWC8244BEETMH6YR7TUKD6GF5Y85WEG-6167a7d0.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/kalibrr-ph/jobs">Kalibrr </a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/South-Jakarta">South Jakarta, Indonesia</a>,
#  <a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/algoritma/jobs"><div><img alt="Algoritma" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="lazy" src="https://rec-data.kalibrr.com/logos/EVAHCC5S9CM5FRRVH6US-5a03dfcf.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/algoritma/jobs">Algoritma</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/Jakarta-Selatan">Jakarta Selatan, Indonesia</a>,
#  <a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/pt-asuransi-allianz-life-indonesia/jobs"><div><img alt="PT Asuransi Allianz Life Indonesia" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="lazy" src="https://rec-data.kalibrr.com/www.kalibrr.ph/logos/FLX7TLPLQUAZD6946SDYDREGYLPERHGEBDAB455P-5d15d2cf.png" width="130"/></div></a>,
#  <a class="k-text-subdued" href="/c/pt-asuransi-allianz-life-indonesia/jobs">PT Asuransi Allianz Life Indonesia</a>,
#  <a class="k-text-subdued k-block" href="/job-board/l/South-Jakarta">South Jakarta, Indonesia</a>]

# %%
post_submit = soup.find_all('span',attrs={'class':'k-block k-mb-1'})
post_submit
# Out:
# [<span class="k-block k-mb-1">Posted 23 days ago • Apply before 29 Oct</span>,
#  <span class="k-block k-mb-1">Posted 12 days ago • Apply before 25 Apr</span>,
#  <span class="k-block k-mb-1">Posted 13 days ago • Apply before 29 Oct</span>,
#  <span class="k-block k-mb-1">Posted 12 days ago • Apply before 17 Dec</span>,
#  <span class="k-block k-mb-1">Posted 4 days ago • Apply before 19 Sep</span>,
#  <span class="k-block k-mb-1">Posted 10 days ago • Apply before 30 Oct</span>,
#  <span class="k-block k-mb-1">Posted 9 days ago • Apply before 30 Sep</span>,
#  <span class="k-block k-mb-1">Posted 16 days ago • Apply before 16 Oct</span>,
#  <span class="k-block k-mb-1">Posted a month ago • Apply before 23 Nov</span>,
#  <span class="k-block k-mb-1">Posted a month ago • Apply before 5 Nov</span>,
#  <span class="k-block k-mb-1">Posted 19 days ago • Apply before 13 Oct</span>,
#  <span class="k-block k-mb-1">Posted 2 months ago • Apply before 29 Sep</span>,
#  <span class="k-block k-mb-1">Posted 2 months ago • Apply before 22 Jun</span>,
#  <span class="k-block k-mb-1">Posted 2 months ago • Apply before 3 Sep</span>,
#  <span class="k-block k-mb-1">Posted 6 days ago • Apply before 30 Oct</span>]

# %%
jobdesc = soup.find_all('div')
jobdesc
# Out:
# [<div data-reactroot="" id="__next"><div class="k-flex k-flex-col k-items-stretch k-min-h-screen k-bg-body"><header class="k-sticky k-flex k-flex-col k-top-0 k-bg-white k-border-b k-border-grey-300 k-z-50"><noscript class="k-bg-red k-text-white"><div class="k-container k-p-4"><strong>Not working?</strong> You need to <a class="k-border-transparent k-border-b k-text-white" href="https://www.activatejavascript.org" target="_blank">enable JavaScript</a> to use Kalibrr.</div></noscript><div class="k-container k-flex k-justify-between md:k-px-4"><a class="k-px-6 k-py-5 md:k-p-6 md:k-border-b-4 k-border-transparent" href="/"><img alt="Kalibrr" class="k-w-auto k-h-8" decoding="async" height="20" src="https://static.kalibrr.com/public/new-kalibrr-logos/kalibrr-logo-blue%403x.min.__f366811b__.png" width="100"/></a><button class="k-px-4 k-text-primary-color k-flex k-items-center k-space-x-2 k-justify-center k-border-transparent md:k-hidden md:k-border-b-4"><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 3c1.66 0 3 1.34 3 3s-1.34 3-3 3-3-1.34-3-3 1.34-3 3-3zm0 14.2c-2.5 0-4.71-1.28-6-3.22.03-1.99 4-3.08 6-3.08 1.99 0 5.97 1.09 6 3.08-1.29 1.94-3.5 3.22-6 3.22z"></path></svg><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7.41 8.59L12 13.17l4.59-4.58L18 10l-6 6-6-6 1.41-1.41z"></path></svg></button><ul class="k-hidden md:k-flex"><li class="k-flex"><a class="k-text-black k-flex k-items-center k-px-4 k-border-b-4 k-border-transparent hover:k-no-underline hover:k-border-primary-color k-border-primary-color" href="/job-board/1">Job Board</a></li><li class="k-flex"><a class="k-text-black k-flex k-items-center k-px-4 k-border-b-4 k-border-transparent hover:k-no-underline hover:k-border-primary-color" href="/employers/">Hire Now</a></li><li class="k-flex"><a class="k-text-black k-flex k-items-center k-px-4 k-border-b-4 k-border-transparent hover:k-no-underline hover:k-border-primary-color" href="/signup">Sign Up</a></li><li class="k-flex"><a class="k-text-black k-flex k-items-center k-px-4 k-border-b-4 k-border-transparent hover:k-no-underline hover:k-border-primary-color" href="/login">Sign In</a></li><li class="k-relative k-flex k-items-center k-border-b-4 k-border-transparent"><button aria-expanded="false" aria-haspopup="true" aria-label="Choose your language" class="k-btn k-ml-2" id="headlessui-listbox-button-undefined" type="button"><svg aria-hidden="true" class="MuiSvgIcon-root k-mr-2" focusable="false" viewbox="0 0 24 24"><path d="M11.99 2C6.47 2 2 6.48 2 12s4.47 10 9.99 10C17.52 22 22 17.52 22 12S17.52 2 11.99 2zm6.93 6h-2.95c-.32-1.25-.78-2.45-1.38-3.56 1.84.63 3.37 1.91 4.33 3.56zM12 4.04c.83 1.2 1.48 2.53 1.91 3.96h-3.82c.43-1.43 1.08-2.76 1.91-3.96zM4.26 14C4.1 13.36 4 12.69 4 12s.1-1.36.26-2h3.38c-.08.66-.14 1.32-.14 2 0 .68.06 1.34.14 2H4.26zm.82 2h2.95c.32 1.25.78 2.45 1.38 3.56-1.84-.63-3.37-1.9-4.33-3.56zm2.95-8H5.08c.96-1.66 2.49-2.93 4.33-3.56C8.81 5.55 8.35 6.75 8.03 8zM12 19.96c-.83-1.2-1.48-2.53-1.91-3.96h3.82c-.43 1.43-1.08 2.76-1.91 3.96zM14.34 14H9.66c-.09-.66-.16-1.32-.16-2 0-.68.07-1.35.16-2h4.68c.09.65.16 1.32.16 2 0 .68-.07 1.34-.16 2zm.25 5.56c.6-1.11 1.06-2.31 1.38-3.56h2.95c-.96 1.65-2.49 2.93-4.33 3.56zM16.36 14c.08-.66.14-1.32.14-2 0-.68-.06-1.34-.14-2h3.38c.16.64.26 1.31.26 2s-.1 1.36-.26 2h-3.38z"></path></svg><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7.41 8.59L12 13.17l4.59-4.58L18 10l-6 6-6-6 1.41-1.41z"></path></svg></button></li></ul></div><div class="k-flex-col md:k-hidden k-hidden"><div class="k-flex k-flex-col k-p-4"><button aria-expanded="false" aria-haspopup="true" aria-label="Choose your language" class="k-flex k-justify-between k-font-normal k-text-subdued k-btn-outline" id="headlessui-listbox-button-undefined" type="button"><svg aria-hidden="true" class="MuiSvgIcon-root k-mr-2" focusa ...
#  <div class="k-flex k-flex-col k-items-stretch k-min-h-screen k-bg-body"><header class="k-sticky k-flex k-flex-col k-top-0 k-bg-white k-border-b k-border-grey-300 k-z-50"><noscript class="k-bg-red k-text-white"><div class="k-container k-p-4"><strong>Not working?</strong> You need to <a class="k-border-transparent k-border-b k-text-white" href="https://www.activatejavascript.org" target="_blank">enable JavaScript</a> to use Kalibrr.</div></noscript><div class="k-container k-flex k-justify-between md:k-px-4"><a class="k-px-6 k-py-5 md:k-p-6 md:k-border-b-4 k-border-transparent" href="/"><img alt="Kalibrr" class="k-w-auto k-h-8" decoding="async" height="20" src="https://static.kalibrr.com/public/new-kalibrr-logos/kalibrr-logo-blue%403x.min.__f366811b__.png" width="100"/></a><button class="k-px-4 k-text-primary-color k-flex k-items-center k-space-x-2 k-justify-center k-border-transparent md:k-hidden md:k-border-b-4"><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 3c1.66 0 3 1.34 3 3s-1.34 3-3 3-3-1.34-3-3 1.34-3 3-3zm0 14.2c-2.5 0-4.71-1.28-6-3.22.03-1.99 4-3.08 6-3.08 1.99 0 5.97 1.09 6 3.08-1.29 1.94-3.5 3.22-6 3.22z"></path></svg><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7.41 8.59L12 13.17l4.59-4.58L18 10l-6 6-6-6 1.41-1.41z"></path></svg></button><ul class="k-hidden md:k-flex"><li class="k-flex"><a class="k-text-black k-flex k-items-center k-px-4 k-border-b-4 k-border-transparent hover:k-no-underline hover:k-border-primary-color k-border-primary-color" href="/job-board/1">Job Board</a></li><li class="k-flex"><a class="k-text-black k-flex k-items-center k-px-4 k-border-b-4 k-border-transparent hover:k-no-underline hover:k-border-primary-color" href="/employers/">Hire Now</a></li><li class="k-flex"><a class="k-text-black k-flex k-items-center k-px-4 k-border-b-4 k-border-transparent hover:k-no-underline hover:k-border-primary-color" href="/signup">Sign Up</a></li><li class="k-flex"><a class="k-text-black k-flex k-items-center k-px-4 k-border-b-4 k-border-transparent hover:k-no-underline hover:k-border-primary-color" href="/login">Sign In</a></li><li class="k-relative k-flex k-items-center k-border-b-4 k-border-transparent"><button aria-expanded="false" aria-haspopup="true" aria-label="Choose your language" class="k-btn k-ml-2" id="headlessui-listbox-button-undefined" type="button"><svg aria-hidden="true" class="MuiSvgIcon-root k-mr-2" focusable="false" viewbox="0 0 24 24"><path d="M11.99 2C6.47 2 2 6.48 2 12s4.47 10 9.99 10C17.52 22 22 17.52 22 12S17.52 2 11.99 2zm6.93 6h-2.95c-.32-1.25-.78-2.45-1.38-3.56 1.84.63 3.37 1.91 4.33 3.56zM12 4.04c.83 1.2 1.48 2.53 1.91 3.96h-3.82c.43-1.43 1.08-2.76 1.91-3.96zM4.26 14C4.1 13.36 4 12.69 4 12s.1-1.36.26-2h3.38c-.08.66-.14 1.32-.14 2 0 .68.06 1.34.14 2H4.26zm.82 2h2.95c.32 1.25.78 2.45 1.38 3.56-1.84-.63-3.37-1.9-4.33-3.56zm2.95-8H5.08c.96-1.66 2.49-2.93 4.33-3.56C8.81 5.55 8.35 6.75 8.03 8zM12 19.96c-.83-1.2-1.48-2.53-1.91-3.96h3.82c-.43 1.43-1.08 2.76-1.91 3.96zM14.34 14H9.66c-.09-.66-.16-1.32-.16-2 0-.68.07-1.35.16-2h4.68c.09.65.16 1.32.16 2 0 .68-.07 1.34-.16 2zm.25 5.56c.6-1.11 1.06-2.31 1.38-3.56h2.95c-.96 1.65-2.49 2.93-4.33 3.56zM16.36 14c.08-.66.14-1.32.14-2 0-.68-.06-1.34-.14-2h3.38c.16.64.26 1.31.26 2s-.1 1.36-.26 2h-3.38z"></path></svg><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7.41 8.59L12 13.17l4.59-4.58L18 10l-6 6-6-6 1.41-1.41z"></path></svg></button></li></ul></div><div class="k-flex-col md:k-hidden k-hidden"><div class="k-flex k-flex-col k-p-4"><button aria-expanded="false" aria-haspopup="true" aria-label="Choose your language" class="k-flex k-justify-between k-font-normal k-text-subdued k-btn-outline" id="headlessui-listbox-button-undefined" type="button"><svg aria-hidden="true" class="MuiSvgIcon-root k-mr-2" focusable="false" viewbox="0 0 24 24"><pa ...
#  <div class="k-container k-p-4"><strong>Not working?</strong> You need to <a class="k-border-transparent k-border-b k-text-white" href="https://www.activatejavascript.org" target="_blank">enable JavaScript</a> to use Kalibrr.</div>,
#  <div class="k-container k-flex k-justify-between md:k-px-4"><a class="k-px-6 k-py-5 md:k-p-6 md:k-border-b-4 k-border-transparent" href="/"><img alt="Kalibrr" class="k-w-auto k-h-8" decoding="async" height="20" src="https://static.kalibrr.com/public/new-kalibrr-logos/kalibrr-logo-blue%403x.min.__f366811b__.png" width="100"/></a><button class="k-px-4 k-text-primary-color k-flex k-items-center k-space-x-2 k-justify-center k-border-transparent md:k-hidden md:k-border-b-4"><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 3c1.66 0 3 1.34 3 3s-1.34 3-3 3-3-1.34-3-3 1.34-3 3-3zm0 14.2c-2.5 0-4.71-1.28-6-3.22.03-1.99 4-3.08 6-3.08 1.99 0 5.97 1.09 6 3.08-1.29 1.94-3.5 3.22-6 3.22z"></path></svg><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7.41 8.59L12 13.17l4.59-4.58L18 10l-6 6-6-6 1.41-1.41z"></path></svg></button><ul class="k-hidden md:k-flex"><li class="k-flex"><a class="k-text-black k-flex k-items-center k-px-4 k-border-b-4 k-border-transparent hover:k-no-underline hover:k-border-primary-color k-border-primary-color" href="/job-board/1">Job Board</a></li><li class="k-flex"><a class="k-text-black k-flex k-items-center k-px-4 k-border-b-4 k-border-transparent hover:k-no-underline hover:k-border-primary-color" href="/employers/">Hire Now</a></li><li class="k-flex"><a class="k-text-black k-flex k-items-center k-px-4 k-border-b-4 k-border-transparent hover:k-no-underline hover:k-border-primary-color" href="/signup">Sign Up</a></li><li class="k-flex"><a class="k-text-black k-flex k-items-center k-px-4 k-border-b-4 k-border-transparent hover:k-no-underline hover:k-border-primary-color" href="/login">Sign In</a></li><li class="k-relative k-flex k-items-center k-border-b-4 k-border-transparent"><button aria-expanded="false" aria-haspopup="true" aria-label="Choose your language" class="k-btn k-ml-2" id="headlessui-listbox-button-undefined" type="button"><svg aria-hidden="true" class="MuiSvgIcon-root k-mr-2" focusable="false" viewbox="0 0 24 24"><path d="M11.99 2C6.47 2 2 6.48 2 12s4.47 10 9.99 10C17.52 22 22 17.52 22 12S17.52 2 11.99 2zm6.93 6h-2.95c-.32-1.25-.78-2.45-1.38-3.56 1.84.63 3.37 1.91 4.33 3.56zM12 4.04c.83 1.2 1.48 2.53 1.91 3.96h-3.82c.43-1.43 1.08-2.76 1.91-3.96zM4.26 14C4.1 13.36 4 12.69 4 12s.1-1.36.26-2h3.38c-.08.66-.14 1.32-.14 2 0 .68.06 1.34.14 2H4.26zm.82 2h2.95c.32 1.25.78 2.45 1.38 3.56-1.84-.63-3.37-1.9-4.33-3.56zm2.95-8H5.08c.96-1.66 2.49-2.93 4.33-3.56C8.81 5.55 8.35 6.75 8.03 8zM12 19.96c-.83-1.2-1.48-2.53-1.91-3.96h3.82c-.43 1.43-1.08 2.76-1.91 3.96zM14.34 14H9.66c-.09-.66-.16-1.32-.16-2 0-.68.07-1.35.16-2h4.68c.09.65.16 1.32.16 2 0 .68-.07 1.34-.16 2zm.25 5.56c.6-1.11 1.06-2.31 1.38-3.56h2.95c-.96 1.65-2.49 2.93-4.33 3.56zM16.36 14c.08-.66.14-1.32.14-2 0-.68-.06-1.34-.14-2h3.38c.16.64.26 1.31.26 2s-.1 1.36-.26 2h-3.38z"></path></svg><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7.41 8.59L12 13.17l4.59-4.58L18 10l-6 6-6-6 1.41-1.41z"></path></svg></button></li></ul></div>,
#  <div class="k-flex-col md:k-hidden k-hidden"><div class="k-flex k-flex-col k-p-4"><button aria-expanded="false" aria-haspopup="true" aria-label="Choose your language" class="k-flex k-justify-between k-font-normal k-text-subdued k-btn-outline" id="headlessui-listbox-button-undefined" type="button"><svg aria-hidden="true" class="MuiSvgIcon-root k-mr-2" focusable="false" viewbox="0 0 24 24"><path d="M11.99 2C6.47 2 2 6.48 2 12s4.47 10 9.99 10C17.52 22 22 17.52 22 12S17.52 2 11.99 2zm6.93 6h-2.95c-.32-1.25-.78-2.45-1.38-3.56 1.84.63 3.37 1.91 4.33 3.56zM12 4.04c.83 1.2 1.48 2.53 1.91 3.96h-3.82c.43-1.43 1.08-2.76 1.91-3.96zM4.26 14C4.1 13.36 4 12.69 4 12s.1-1.36.26-2h3.38c-.08.66-.14 1.32-.14 2 0 .68.06 1.34.14 2H4.26zm.82 2h2.95c.32 1.25.78 2.45 1.38 3.56-1.84-.63-3.37-1.9-4.33-3.56zm2.95-8H5.08c.96-1.66 2.49-2.93 4.33-3.56C8.81 5.55 8.35 6.75 8.03 8zM12 19.96c-.83-1.2-1.48-2.53-1.91-3.96h3.82c-.43 1.43-1.08 2.76-1.91 3.96zM14.34 14H9.66c-.09-.66-.16-1.32-.16-2 0-.68.07-1.35.16-2h4.68c.09.65.16 1.32.16 2 0 .68-.07 1.34-.16 2zm.25 5.56c.6-1.11 1.06-2.31 1.38-3.56h2.95c-.96 1.65-2.49 2.93-4.33 3.56zM16.36 14c.08-.66.14-1.32.14-2 0-.68-.06-1.34-.14-2h3.38c.16.64.26 1.31.26 2s-.1 1.36-.26 2h-3.38z"></path></svg>English<svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7.41 8.59L12 13.17l4.59-4.58L18 10l-6 6-6-6 1.41-1.41z"></path></svg></button></div><div class="k-flex k-justify-between"><a class="k-text-black k-inline-flex k-flex-1 k-justify-center k-p-4 hover:k-no-underline" href="/signup">Sign Up</a><a class="k-text-black k-inline-flex k-flex-1 k-justify-center k-p-4 hover:k-no-underline" href="/login">Sign In</a></div></div>,
#  <div class="k-flex k-flex-col k-p-4"><button aria-expanded="false" aria-haspopup="true" aria-label="Choose your language" class="k-flex k-justify-between k-font-normal k-text-subdued k-btn-outline" id="headlessui-listbox-button-undefined" type="button"><svg aria-hidden="true" class="MuiSvgIcon-root k-mr-2" focusable="false" viewbox="0 0 24 24"><path d="M11.99 2C6.47 2 2 6.48 2 12s4.47 10 9.99 10C17.52 22 22 17.52 22 12S17.52 2 11.99 2zm6.93 6h-2.95c-.32-1.25-.78-2.45-1.38-3.56 1.84.63 3.37 1.91 4.33 3.56zM12 4.04c.83 1.2 1.48 2.53 1.91 3.96h-3.82c.43-1.43 1.08-2.76 1.91-3.96zM4.26 14C4.1 13.36 4 12.69 4 12s.1-1.36.26-2h3.38c-.08.66-.14 1.32-.14 2 0 .68.06 1.34.14 2H4.26zm.82 2h2.95c.32 1.25.78 2.45 1.38 3.56-1.84-.63-3.37-1.9-4.33-3.56zm2.95-8H5.08c.96-1.66 2.49-2.93 4.33-3.56C8.81 5.55 8.35 6.75 8.03 8zM12 19.96c-.83-1.2-1.48-2.53-1.91-3.96h3.82c-.43 1.43-1.08 2.76-1.91 3.96zM14.34 14H9.66c-.09-.66-.16-1.32-.16-2 0-.68.07-1.35.16-2h4.68c.09.65.16 1.32.16 2 0 .68-.07 1.34-.16 2zm.25 5.56c.6-1.11 1.06-2.31 1.38-3.56h2.95c-.96 1.65-2.49 2.93-4.33 3.56zM16.36 14c.08-.66.14-1.32.14-2 0-.68-.06-1.34-.14-2h3.38c.16.64.26 1.31.26 2s-.1 1.36-.26 2h-3.38z"></path></svg>English<svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7.41 8.59L12 13.17l4.59-4.58L18 10l-6 6-6-6 1.41-1.41z"></path></svg></button></div>,
#  <div class="k-flex k-justify-between"><a class="k-text-black k-inline-flex k-flex-1 k-justify-center k-p-4 hover:k-no-underline" href="/signup">Sign Up</a><a class="k-text-black k-inline-flex k-flex-1 k-justify-center k-p-4 hover:k-no-underline" href="/login">Sign In</a></div>,
#  <div class="k-container k-my-4"><div><k-text-input fieldtype="search" large="true" placeholder="Search for job posts, companies, location..." value="data"><div class="k-flex" slot="inset-end"><button class="k-btn-tertiary k-m-2 k-mr-1 k-p-2 k-block md:k-mr-0 lg:k-hidden"><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" height="24" viewbox="0 0 24 24" width="24"><path d="M10 18h4v-2h-4v2zM3 6v2h18V6H3zm3 7h12v-2H6v2z"></path></svg></button><button class="k-btn-primary k-m-2"><span class="md:k-hidden"><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" height="24" viewbox="0 0 24 24" width="24"><path d="M15.5 14h-.79l-.28-.27C15.41 12.59 16 11.11 16 9.5 16 5.91 13.09 3 9.5 3S3 5.91 3 9.5 5.91 16 9.5 16c1.61 0 3.09-.59 4.23-1.57l.27.28v.79l5 4.99L20.49 19l-4.99-5zm-6 0C7.01 14 5 11.99 5 9.5S7.01 5 9.5 5 14 7.01 14 9.5 11.99 14 9.5 14z"></path></svg></span><span class="k-hidden md:k-inline">Search</span></button></div></k-text-input><div class="k-hidden k-flex-col k-my-2 k-px-4 k-block lg:k-flex-row lg:k-flex"><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Location</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Job level</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Employment Type</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Job function</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Education</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Company</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Salary</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-p-2 k-flex k-items-center k-text-caption k-text-subdued"><input id="jb-rf ...
#  <div><k-text-input fieldtype="search" large="true" placeholder="Search for job posts, companies, location..." value="data"><div class="k-flex" slot="inset-end"><button class="k-btn-tertiary k-m-2 k-mr-1 k-p-2 k-block md:k-mr-0 lg:k-hidden"><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" height="24" viewbox="0 0 24 24" width="24"><path d="M10 18h4v-2h-4v2zM3 6v2h18V6H3zm3 7h12v-2H6v2z"></path></svg></button><button class="k-btn-primary k-m-2"><span class="md:k-hidden"><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" height="24" viewbox="0 0 24 24" width="24"><path d="M15.5 14h-.79l-.28-.27C15.41 12.59 16 11.11 16 9.5 16 5.91 13.09 3 9.5 3S3 5.91 3 9.5 5.91 16 9.5 16c1.61 0 3.09-.59 4.23-1.57l.27.28v.79l5 4.99L20.49 19l-4.99-5zm-6 0C7.01 14 5 11.99 5 9.5S7.01 5 9.5 5 14 7.01 14 9.5 11.99 14 9.5 14z"></path></svg></span><span class="k-hidden md:k-inline">Search</span></button></div></k-text-input><div class="k-hidden k-flex-col k-my-2 k-px-4 k-block lg:k-flex-row lg:k-flex"><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Location</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Job level</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Employment Type</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Job function</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Education</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Company</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Salary</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-p-2 k-flex k-items-center k-text-caption k-text-subdued"><input id="jb-rf-filter-cb" name="jb-rf-filter-c ...
#  <div class="k-flex" slot="inset-end"><button class="k-btn-tertiary k-m-2 k-mr-1 k-p-2 k-block md:k-mr-0 lg:k-hidden"><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" height="24" viewbox="0 0 24 24" width="24"><path d="M10 18h4v-2h-4v2zM3 6v2h18V6H3zm3 7h12v-2H6v2z"></path></svg></button><button class="k-btn-primary k-m-2"><span class="md:k-hidden"><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" height="24" viewbox="0 0 24 24" width="24"><path d="M15.5 14h-.79l-.28-.27C15.41 12.59 16 11.11 16 9.5 16 5.91 13.09 3 9.5 3S3 5.91 3 9.5 5.91 16 9.5 16c1.61 0 3.09-.59 4.23-1.57l.27.28v.79l5 4.99L20.49 19l-4.99-5zm-6 0C7.01 14 5 11.99 5 9.5S7.01 5 9.5 5 14 7.01 14 9.5 11.99 14 9.5 14z"></path></svg></span><span class="k-hidden md:k-inline">Search</span></button></div>,
#  <div class="k-hidden k-flex-col k-my-2 k-px-4 k-block lg:k-flex-row lg:k-flex"><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Location</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Job level</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Employment Type</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Job function</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Education</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Company</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Salary</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div><div class="k-p-2 k-flex k-items-center k-text-caption k-text-subdued"><input id="jb-rf-filter-cb" name="jb-rf-filter-cb" type="checkbox"/><label class="k-ml-2" for="jb-rf-filter-cb">Responds Fast</label></div></div>,
#  <div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Location</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div>,
#  <div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Job level</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div>,
#  <div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Employment Type</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div>,
#  <div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Job function</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div>,
#  <div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Education</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div>,
#  <div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Company</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div>,
#  <div class="k-relative k-flex k-items-stretch lg:k-flex-none"><button aria-expanded="false" class="k-p-2 k-text-caption k-flex k-justify-between k-w-full lg:k-w-auto k-rounded k-text-subdued" id="headlessui-popover-button-undefined" type="button"><span>Salary</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div>,
#  <div class="k-p-2 k-flex k-items-center k-text-caption k-text-subdued"><input id="jb-rf-filter-cb" name="jb-rf-filter-cb" type="checkbox"/><label class="k-ml-2" for="jb-rf-filter-cb">Responds Fast</label></div>,
#  <div class="k-flex k-py-4 k-overflow-x-scroll lg:k-overflow-x-auto"><div class="k-inline-flex k-items-center k-ml-2 first:k-ml-4 last:k-mr-4 k-p-1 k-pl-2 k-rounded-full k-bg-secondary-color k-text-white k-text-caption k-whitespace-nowrap"><span>Text:</span><strong> <!-- -->data</strong><button class="k-inline-flex k-rounded-full k-ml-2 k-p-0.5 k-bg-secondary-color-500"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeSmall" focusable="false" viewbox="0 0 24 24"><path d="M19 6.41L17.59 5 12 10.59 6.41 5 5 6.41 10.59 12 5 17.59 6.41 19 12 13.41 17.59 19 19 17.59 13.41 12z"></path></svg></button></div></div>,
#  <div class="k-inline-flex k-items-center k-ml-2 first:k-ml-4 last:k-mr-4 k-p-1 k-pl-2 k-rounded-full k-bg-secondary-color k-text-white k-text-caption k-whitespace-nowrap"><span>Text:</span><strong> <!-- -->data</strong><button class="k-inline-flex k-rounded-full k-ml-2 k-p-0.5 k-bg-secondary-color-500"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeSmall" focusable="false" viewbox="0 0 24 24"><path d="M19 6.41L17.59 5 12 10.59 6.41 5 5 6.41 10.59 12 5 17.59 6.41 19 12 13.41 17.59 19 19 17.59 13.41 12z"></path></svg></button></div>,
#  <div class="k-mx-4 k-my-4 k-bg-white k-rounded-md k-p-4 k-border k-border-tertiary-color k-shadow md:k-py-8"><div class="k-w-full k-break-words"><h1 class="k-text-xl k-font-bold k-mb-2 md:k-text-title">Find remote work for data faster</h1></div><div class="lg:k-items-center"><p class="k-text-caption k-text-subdued md:k-flex-shrink k-my-4">Kalibrr knows how hard it is to look for work in these trying times. That's why we've made it easier to look for jobs that allow you to work from home or wherever you are. Try these remote work filters out!</p><div class="k-flex k-flex-col k-mt-4 k-space-y-4 hover:k-cursor-pointer md:k-flex-row md:k-flex-grow md:k-flex-1 md:k-space-x-4 md:k-items-center md:k-space-y-0 lg:k-mt-0 lg:k-mr-4"><a aria-checked="false" class="k-inline-flex k-font-semibold k-bg-grey-200 k-rounded-full k-px-4 k-py-2 k-items-center k-outline-none md:k-whitespace-nowrap hover:k-bg-primary-color hover:k-text-white focus:k-border-2 focus:k-border-grey-700 k-text-grey-700" href="/job-board/te/data/t/full-time/work_from_home/y/1" role="switch"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeSmall" focusable="false" height="20" viewbox="0 0 24 24" width="20"><path d="M22 5.72l-4.6-3.86-1.29 1.53 4.6 3.86L22 5.72zM7.88 3.39L6.6 1.86 2 5.71l1.29 1.53 4.59-3.85zM12.5 8H11v6l4.75 2.85.75-1.23-4-2.37V8zM12 4c-4.97 0-9 4.03-9 9s4.02 9 9 9c4.97 0 9-4.03 9-9s-4.03-9-9-9zm0 16c-3.87 0-7-3.13-7-7s3.13-7 7-7 7 3.13 7 7-3.13 7-7 7z"></path></svg><span class="k-ml-2">Full time</span></a><a aria-checked="false" class="k-inline-flex k-font-semibold k-bg-grey-200 k-rounded-full k-px-4 k-py-2 k-items-center k-outline-none md:k-whitespace-nowrap hover:k-bg-primary-color hover:k-text-white focus:k-border-2 focus:k-border-grey-700 k-text-grey-700" href="/job-board/te/data/t/part-time/work_from_home/y/1" role="switch"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeSmall" focusable="false" height="20" viewbox="0 0 24 24" width="20"><path d="M6 2v6h.01L6 8.01 10 12l-4 4 .01.01H6V22h12v-5.99h-.01L18 16l-4-4 4-3.99-.01-.01H18V2H6z"></path></svg><span class="k-ml-2">Part time</span></a><a aria-checked="false" class="k-inline-flex k-font-semibold k-bg-grey-200 k-rounded-full k-px-4 k-py-2 k-items-center k-outline-none md:k-whitespace-nowrap hover:k-bg-primary-color hover:k-text-white focus:k-border-2 focus:k-border-grey-700 k-text-grey-700" href="/job-board/te/data/t/freelance/work_from_home/y/1" role="switch"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeSmall" focusable="false" height="20" viewbox="0 0 24 24" width="20"><path d="M20 3H4v10c0 2.21 1.79 4 4 4h6c2.21 0 4-1.79 4-4v-3h2c1.11 0 2-.9 2-2V5c0-1.11-.89-2-2-2zm0 5h-2V5h2v3zM4 19h16v2H4z"></path></svg><span class="k-ml-2">Freelance</span></a><a aria-checked="false" class="k-inline-flex k-font-semibold k-bg-grey-200 k-rounded-full k-px-4 k-py-2 k-items-center k-outline-none md:k-whitespace-nowrap hover:k-bg-primary-color hover:k-text-white focus:k-border-2 focus:k-border-grey-700 k-text-grey-700" href="/job-board/te/data/t/contractual/work_from_home/y/1" role="switch"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeSmall" focusable="false" height="20" viewbox="0 0 24 24" width="20"><path d="M14 2H6c-1.1 0-1.99.9-1.99 2L4 20c0 1.1.89 2 1.99 2H18c1.1 0 2-.9 2-2V8l-6-6zm2 16H8v-2h8v2zm0-4H8v-2h8v2zm-3-5V3.5L18.5 9H13z"></path></svg><span class="k-ml-2">Contractual</span></a></div></div></div>,
#  <div class="k-w-full k-break-words"><h1 class="k-text-xl k-font-bold k-mb-2 md:k-text-title">Find remote work for data faster</h1></div>,
#  <div class="lg:k-items-center"><p class="k-text-caption k-text-subdued md:k-flex-shrink k-my-4">Kalibrr knows how hard it is to look for work in these trying times. That's why we've made it easier to look for jobs that allow you to work from home or wherever you are. Try these remote work filters out!</p><div class="k-flex k-flex-col k-mt-4 k-space-y-4 hover:k-cursor-pointer md:k-flex-row md:k-flex-grow md:k-flex-1 md:k-space-x-4 md:k-items-center md:k-space-y-0 lg:k-mt-0 lg:k-mr-4"><a aria-checked="false" class="k-inline-flex k-font-semibold k-bg-grey-200 k-rounded-full k-px-4 k-py-2 k-items-center k-outline-none md:k-whitespace-nowrap hover:k-bg-primary-color hover:k-text-white focus:k-border-2 focus:k-border-grey-700 k-text-grey-700" href="/job-board/te/data/t/full-time/work_from_home/y/1" role="switch"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeSmall" focusable="false" height="20" viewbox="0 0 24 24" width="20"><path d="M22 5.72l-4.6-3.86-1.29 1.53 4.6 3.86L22 5.72zM7.88 3.39L6.6 1.86 2 5.71l1.29 1.53 4.59-3.85zM12.5 8H11v6l4.75 2.85.75-1.23-4-2.37V8zM12 4c-4.97 0-9 4.03-9 9s4.02 9 9 9c4.97 0 9-4.03 9-9s-4.03-9-9-9zm0 16c-3.87 0-7-3.13-7-7s3.13-7 7-7 7 3.13 7 7-3.13 7-7 7z"></path></svg><span class="k-ml-2">Full time</span></a><a aria-checked="false" class="k-inline-flex k-font-semibold k-bg-grey-200 k-rounded-full k-px-4 k-py-2 k-items-center k-outline-none md:k-whitespace-nowrap hover:k-bg-primary-color hover:k-text-white focus:k-border-2 focus:k-border-grey-700 k-text-grey-700" href="/job-board/te/data/t/part-time/work_from_home/y/1" role="switch"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeSmall" focusable="false" height="20" viewbox="0 0 24 24" width="20"><path d="M6 2v6h.01L6 8.01 10 12l-4 4 .01.01H6V22h12v-5.99h-.01L18 16l-4-4 4-3.99-.01-.01H18V2H6z"></path></svg><span class="k-ml-2">Part time</span></a><a aria-checked="false" class="k-inline-flex k-font-semibold k-bg-grey-200 k-rounded-full k-px-4 k-py-2 k-items-center k-outline-none md:k-whitespace-nowrap hover:k-bg-primary-color hover:k-text-white focus:k-border-2 focus:k-border-grey-700 k-text-grey-700" href="/job-board/te/data/t/freelance/work_from_home/y/1" role="switch"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeSmall" focusable="false" height="20" viewbox="0 0 24 24" width="20"><path d="M20 3H4v10c0 2.21 1.79 4 4 4h6c2.21 0 4-1.79 4-4v-3h2c1.11 0 2-.9 2-2V5c0-1.11-.89-2-2-2zm0 5h-2V5h2v3zM4 19h16v2H4z"></path></svg><span class="k-ml-2">Freelance</span></a><a aria-checked="false" class="k-inline-flex k-font-semibold k-bg-grey-200 k-rounded-full k-px-4 k-py-2 k-items-center k-outline-none md:k-whitespace-nowrap hover:k-bg-primary-color hover:k-text-white focus:k-border-2 focus:k-border-grey-700 k-text-grey-700" href="/job-board/te/data/t/contractual/work_from_home/y/1" role="switch"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeSmall" focusable="false" height="20" viewbox="0 0 24 24" width="20"><path d="M14 2H6c-1.1 0-1.99.9-1.99 2L4 20c0 1.1.89 2 1.99 2H18c1.1 0 2-.9 2-2V8l-6-6zm2 16H8v-2h8v2zm0-4H8v-2h8v2zm-3-5V3.5L18.5 9H13z"></path></svg><span class="k-ml-2">Contractual</span></a></div></div>,
#  <div class="k-flex k-flex-col k-mt-4 k-space-y-4 hover:k-cursor-pointer md:k-flex-row md:k-flex-grow md:k-flex-1 md:k-space-x-4 md:k-items-center md:k-space-y-0 lg:k-mt-0 lg:k-mr-4"><a aria-checked="false" class="k-inline-flex k-font-semibold k-bg-grey-200 k-rounded-full k-px-4 k-py-2 k-items-center k-outline-none md:k-whitespace-nowrap hover:k-bg-primary-color hover:k-text-white focus:k-border-2 focus:k-border-grey-700 k-text-grey-700" href="/job-board/te/data/t/full-time/work_from_home/y/1" role="switch"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeSmall" focusable="false" height="20" viewbox="0 0 24 24" width="20"><path d="M22 5.72l-4.6-3.86-1.29 1.53 4.6 3.86L22 5.72zM7.88 3.39L6.6 1.86 2 5.71l1.29 1.53 4.59-3.85zM12.5 8H11v6l4.75 2.85.75-1.23-4-2.37V8zM12 4c-4.97 0-9 4.03-9 9s4.02 9 9 9c4.97 0 9-4.03 9-9s-4.03-9-9-9zm0 16c-3.87 0-7-3.13-7-7s3.13-7 7-7 7 3.13 7 7-3.13 7-7 7z"></path></svg><span class="k-ml-2">Full time</span></a><a aria-checked="false" class="k-inline-flex k-font-semibold k-bg-grey-200 k-rounded-full k-px-4 k-py-2 k-items-center k-outline-none md:k-whitespace-nowrap hover:k-bg-primary-color hover:k-text-white focus:k-border-2 focus:k-border-grey-700 k-text-grey-700" href="/job-board/te/data/t/part-time/work_from_home/y/1" role="switch"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeSmall" focusable="false" height="20" viewbox="0 0 24 24" width="20"><path d="M6 2v6h.01L6 8.01 10 12l-4 4 .01.01H6V22h12v-5.99h-.01L18 16l-4-4 4-3.99-.01-.01H18V2H6z"></path></svg><span class="k-ml-2">Part time</span></a><a aria-checked="false" class="k-inline-flex k-font-semibold k-bg-grey-200 k-rounded-full k-px-4 k-py-2 k-items-center k-outline-none md:k-whitespace-nowrap hover:k-bg-primary-color hover:k-text-white focus:k-border-2 focus:k-border-grey-700 k-text-grey-700" href="/job-board/te/data/t/freelance/work_from_home/y/1" role="switch"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeSmall" focusable="false" height="20" viewbox="0 0 24 24" width="20"><path d="M20 3H4v10c0 2.21 1.79 4 4 4h6c2.21 0 4-1.79 4-4v-3h2c1.11 0 2-.9 2-2V5c0-1.11-.89-2-2-2zm0 5h-2V5h2v3zM4 19h16v2H4z"></path></svg><span class="k-ml-2">Freelance</span></a><a aria-checked="false" class="k-inline-flex k-font-semibold k-bg-grey-200 k-rounded-full k-px-4 k-py-2 k-items-center k-outline-none md:k-whitespace-nowrap hover:k-bg-primary-color hover:k-text-white focus:k-border-2 focus:k-border-grey-700 k-text-grey-700" href="/job-board/te/data/t/contractual/work_from_home/y/1" role="switch"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeSmall" focusable="false" height="20" viewbox="0 0 24 24" width="20"><path d="M14 2H6c-1.1 0-1.99.9-1.99 2L4 20c0 1.1.89 2 1.99 2H18c1.1 0 2-.9 2-2V8l-6-6zm2 16H8v-2h8v2zm0-4H8v-2h8v2zm-3-5V3.5L18.5 9H13z"></path></svg><span class="k-ml-2">Contractual</span></a></div>,
#  <div><style data-emotion="css 12k1os7">.css-12k1os7{grid-template-columns:0.75fr 0.25fr;grid-template-rows:auto auto;}</style><div class="k-container k-grid k-my-4 md:k-my-8 lg:k-px-4 css-12k1os7"><aside class="k-col-span-2 lg:k-col-span-1 lg:k-col-start-2 lg:k-row-start-1 lg:k-row-span-2 lg:k-ml-4"></aside><main class="k-row-start-2 k-col-span-2 md:k-px-4 lg:k-px-0 lg:k-row-start-1 lg:k-row-span-2"><div class="k-m-4 k-flex k-flex-col md:k-flex-row md:k-items-center md:k-mx-0 md:k-my-2"><span class="k-text-caption k-text-subdued">1<!-- --> - <!-- -->15<!-- --> of <!-- -->918<!-- --> job matches</span><div class="k-hidden k-relative k-mx-2 k-my-2 md:k-block"><button aria-expanded="false" aria-haspopup="true" class="k-flex k-items-center k-justify-between k-w-full k-text-caption k-text-subdued k-rounded k-p-2" id="headlessui-listbox-button-undefined" type="button"><span>Sort by relevance</span><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M7 10l5 5 5-5z"></path></svg></button></div></div><div class="k-border-b k-border-t k-border-tertiary-ghost-color md:k-border md:k-overflow-hidden md:k-rounded-lg"><div class="k-bg-white k-divide-y k-divide-solid k-divide-tertiary-ghost-color" itemscope="" itemtype="http://schema.org/ItemList"><style data-emotion="css 1b4vug6">.css-1b4vug6{grid-template-columns:5rem 1rem auto 1rem max-content;grid-template-rows:auto 0.25rem auto;}</style><div class="k-grid k-border-tertiary-ghost-color k-text-sm k-p-4 md:k-p-6 css-1b4vug6" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a class="k-bg-white k-flex k-items-center k-flex-shrink k-justify-center k-text-4xl k-text-subdued k-overflow-hidden k-px-4 k-py-2 k-row-span-4" href="/c/pt-berlian-sistem-informasi/jobs"><div><img alt="PT Berlian Sistem Informasi" class="k-block k-max-w-full k-max-h-full k-bg-white k-mx-auto" decoding="async" height="80" loading="eager" src="https://rec-data.kalibrr.com/www.kalibrr.com/logos/HELY75DFBQLJMNBNXJWB4LJCAZRYW7WPUJLN8CUH-649a6aba.png" width="130"/></div></a><div class="k-col-start-3 k-row-start-1"><h2 class="k-text-xl k-font-medium"><a class="k-text-primary-color" href="/c/pt-berlian-sistem-informasi/jobs/204136/data-analyst-2" itemprop="name">Data Analyst</a></h2></div><style data-emotion="css 1gzvnis">.css-1gzvnis{display:-webkit-box!important;-webkit-line-clamp:2;-webkit-box-orient:vertical;}</style><div class="k-text-xs k-text-subdued k-col-start-1 k-row-start-5 k-col-span-3 k-mt-7 k-h-8 k-text-ellipsis k-overflow-hidden k-whitespace-normal css-1gzvnis"><div class=""></div></div><div class="k-col-start-3 k-row-start-3 k-flex k-flex-col k-justify-end"><span class="k-inline-flex k-items-center k-mb-1"><a class="k-text-subdued" href="/c/pt-berlian-sistem-informasi/jobs">PT Berlian Sistem Informasi</a><span class="k-ml-1 k-mb-0.5"><div class="" style="display:inline" title="verified-business"><svg aria-hidden="true" class="MuiSvgIcon-root k-text-primary-color-500 MuiSvgIcon-fontSizeSmall" focusable="false" height="20" viewbox="0 0 24 24" width="20"><path d="M12 1L3 5v6c0 5.55 3.84 10.74 9 12 5.16-1.26 9-6.45 9-12V5l-9-4zm-2 16l-4-4 1.41-1.41L10 14.17l6.59-6.59L18 9l-8 8z"></path></svg></div></span></span><div class="k-flex k-flex-col md:k-flex-row"><a class="k-text-subdued k-block" href="/job-board/l/East-Jakarta">East Jakarta, Indonesia</a></div></div><div class="k-col-start-5 k-row-start-1 k-text-right k-text-xs k-text-subdued k-hidden k-mb-2 md:k-block"><span class="k-block k-mb-1">Posted 23 days ago • Apply before 29 Oct</span><span class="k-block">Recruiter was hiring 2 days ago</span></div><div class="k-col-start-5 k-row-start-1 md:k-flex md:k-justify-end md:k-items-end md:k-row-start-3"><div class="k-grid k-grid-rows-3"><button class="k-btn-tertiary k-inline-flex k-items-center k-justify-center k-row-start-1 k-row-span-2 md:k-row-start-2"><svg aria-hidden="true" class="MuiSvgIcon-root md:k-mr-2" focusable="false" viewbox="0 0 24 2 ...
# ...
#  <div class="k-flex k-flex-col k-container k-px-4 k-py-12 md:k-py-16"><div class="k-flex k-flex-col md:k-flex-row md:k-gap-20"><div><a class="k-block k-mb-4" href="/"><img alt="Kalibrr" decoding="async" height="33" loading="lazy" src="https://static.kalibrr.com/public/new-kalibrr-logos/kalibrr-logo-blue.__ba9f70be__.svg" width="116"/></a><p>We transform the way candidates find jobs and companies hire talent.</p><div class="k-my-8 md:k-justify-between sm:k-w-full lg:k-w-10/12"><div class="k-flex k-justify-center k-flex-wrap md:k-flex-nowrap k-mb-8 md:k-mb-0"><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://itunes.apple.com/ph/app/kalibrr-job-search/id1271990503" rel="noopener" target="_blank"><img alt="Download on the App Store" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-ios_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-ios_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-ios_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-ios.png 3x" width="160"/></a><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://play.google.com/store/apps/details?id=com.kalibrr&amp;referrer=utm_source%3Dkalibrr-website%26utm_medium%3Dbanner%26utm_campaign%3Dhomepage-jan12" rel="noopener" target="_blank"><img alt="Get it on Google Play" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-playstore_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-playstore_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-playstore_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-playstore.png 3x" width="160"/></a><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://appgallery.huawei.com/#/app/C102650235" rel="noopener" target="_blank"><img alt="Download on AppGallery" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-huawei_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-huawei_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-huawei_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-huawei.png 3x" width="160"/></a></div></div></div><div class="k-flex k-flex-col k-justify-between k-my-8 md:k-flex-row md:k-w-8/12 lg:k-w-6/12"><div class="k-mb-4"><h3 class="k-font-semibold k-text-primary-color">Job Seekers</h3><ul><li class="k-my-2"><a class="k-text-black" href="/signup">Sign Up</a></li><li class="k-my-2"><a class="k-text-black" href="/job-board">Job Board</a></li><li class="k-my-2"><a class="k-text-black" href="/job-category">Job Category</a></li><li class="k-my-2"><a class="k-text-black" href="/jobseeker-guide">Jobseeker Guide</a></li></ul></div><div class="k-mb-4"><h3 class="k-font-semibold k-text-primary-color">Employers</h3><ul><li class="k-my-2"><a class="k-text-black" href="/employers/">Start Hiring</a></li><li class="k-my-2"><a class="k-text-black" href="/sourcing">Kalibrr Sourcing</a></li><li class="k-my-2"><a class="k-text-black" href="/contactus">Kalibrr Partnership</a></li></ul></div><div class="k-mb-4"><h3 class="k-font-semibold k-text-primary-color">About Kalibrr</h3><ul><li class="k-my-2"><a class="k-text-black" href="/about">About</a></li><li class="k-my-2"><a class="k-text-black" href="/c/kalibrr-ph">Careers</a></li><li class="k-my-2"><a class="k-text-black" href="/blog">Blog</a></li></ul></div></div></div><div class="k-flex k-flex-col k-text-caption k-justify-between k-text-gray-500 md:k-flex-row md:k-justify-start md:k-w-full"><p class="k-mb-4 md:k-mr-4">© <!-- -->2023<!-- --> Kalibrr Inc.</p><p><a class="k-text-gray-500" href="/terms">Terms of Use</a> | <a class="k-text-gray-500" href="/dsa">Data Sharing Policy</a> | <a class="k-text-gray-500" href="/privacy">Privacy Policy</a></p></div></div>,
#  <div class="k-flex k-flex-col md:k-flex-row md:k-gap-20"><div><a class="k-block k-mb-4" href="/"><img alt="Kalibrr" decoding="async" height="33" loading="lazy" src="https://static.kalibrr.com/public/new-kalibrr-logos/kalibrr-logo-blue.__ba9f70be__.svg" width="116"/></a><p>We transform the way candidates find jobs and companies hire talent.</p><div class="k-my-8 md:k-justify-between sm:k-w-full lg:k-w-10/12"><div class="k-flex k-justify-center k-flex-wrap md:k-flex-nowrap k-mb-8 md:k-mb-0"><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://itunes.apple.com/ph/app/kalibrr-job-search/id1271990503" rel="noopener" target="_blank"><img alt="Download on the App Store" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-ios_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-ios_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-ios_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-ios.png 3x" width="160"/></a><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://play.google.com/store/apps/details?id=com.kalibrr&amp;referrer=utm_source%3Dkalibrr-website%26utm_medium%3Dbanner%26utm_campaign%3Dhomepage-jan12" rel="noopener" target="_blank"><img alt="Get it on Google Play" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-playstore_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-playstore_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-playstore_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-playstore.png 3x" width="160"/></a><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://appgallery.huawei.com/#/app/C102650235" rel="noopener" target="_blank"><img alt="Download on AppGallery" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-huawei_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-huawei_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-huawei_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-huawei.png 3x" width="160"/></a></div></div></div><div class="k-flex k-flex-col k-justify-between k-my-8 md:k-flex-row md:k-w-8/12 lg:k-w-6/12"><div class="k-mb-4"><h3 class="k-font-semibold k-text-primary-color">Job Seekers</h3><ul><li class="k-my-2"><a class="k-text-black" href="/signup">Sign Up</a></li><li class="k-my-2"><a class="k-text-black" href="/job-board">Job Board</a></li><li class="k-my-2"><a class="k-text-black" href="/job-category">Job Category</a></li><li class="k-my-2"><a class="k-text-black" href="/jobseeker-guide">Jobseeker Guide</a></li></ul></div><div class="k-mb-4"><h3 class="k-font-semibold k-text-primary-color">Employers</h3><ul><li class="k-my-2"><a class="k-text-black" href="/employers/">Start Hiring</a></li><li class="k-my-2"><a class="k-text-black" href="/sourcing">Kalibrr Sourcing</a></li><li class="k-my-2"><a class="k-text-black" href="/contactus">Kalibrr Partnership</a></li></ul></div><div class="k-mb-4"><h3 class="k-font-semibold k-text-primary-color">About Kalibrr</h3><ul><li class="k-my-2"><a class="k-text-black" href="/about">About</a></li><li class="k-my-2"><a class="k-text-black" href="/c/kalibrr-ph">Careers</a></li><li class="k-my-2"><a class="k-text-black" href="/blog">Blog</a></li></ul></div></div></div>,
#  <div><a class="k-block k-mb-4" href="/"><img alt="Kalibrr" decoding="async" height="33" loading="lazy" src="https://static.kalibrr.com/public/new-kalibrr-logos/kalibrr-logo-blue.__ba9f70be__.svg" width="116"/></a><p>We transform the way candidates find jobs and companies hire talent.</p><div class="k-my-8 md:k-justify-between sm:k-w-full lg:k-w-10/12"><div class="k-flex k-justify-center k-flex-wrap md:k-flex-nowrap k-mb-8 md:k-mb-0"><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://itunes.apple.com/ph/app/kalibrr-job-search/id1271990503" rel="noopener" target="_blank"><img alt="Download on the App Store" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-ios_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-ios_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-ios_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-ios.png 3x" width="160"/></a><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://play.google.com/store/apps/details?id=com.kalibrr&amp;referrer=utm_source%3Dkalibrr-website%26utm_medium%3Dbanner%26utm_campaign%3Dhomepage-jan12" rel="noopener" target="_blank"><img alt="Get it on Google Play" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-playstore_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-playstore_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-playstore_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-playstore.png 3x" width="160"/></a><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://appgallery.huawei.com/#/app/C102650235" rel="noopener" target="_blank"><img alt="Download on AppGallery" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-huawei_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-huawei_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-huawei_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-huawei.png 3x" width="160"/></a></div></div></div>,
#  <div class="k-my-8 md:k-justify-between sm:k-w-full lg:k-w-10/12"><div class="k-flex k-justify-center k-flex-wrap md:k-flex-nowrap k-mb-8 md:k-mb-0"><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://itunes.apple.com/ph/app/kalibrr-job-search/id1271990503" rel="noopener" target="_blank"><img alt="Download on the App Store" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-ios_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-ios_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-ios_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-ios.png 3x" width="160"/></a><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://play.google.com/store/apps/details?id=com.kalibrr&amp;referrer=utm_source%3Dkalibrr-website%26utm_medium%3Dbanner%26utm_campaign%3Dhomepage-jan12" rel="noopener" target="_blank"><img alt="Get it on Google Play" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-playstore_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-playstore_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-playstore_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-playstore.png 3x" width="160"/></a><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://appgallery.huawei.com/#/app/C102650235" rel="noopener" target="_blank"><img alt="Download on AppGallery" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-huawei_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-huawei_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-huawei_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-huawei.png 3x" width="160"/></a></div></div>,
#  <div class="k-flex k-justify-center k-flex-wrap md:k-flex-nowrap k-mb-8 md:k-mb-0"><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://itunes.apple.com/ph/app/kalibrr-job-search/id1271990503" rel="noopener" target="_blank"><img alt="Download on the App Store" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-ios_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-ios_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-ios_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-ios.png 3x" width="160"/></a><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://play.google.com/store/apps/details?id=com.kalibrr&amp;referrer=utm_source%3Dkalibrr-website%26utm_medium%3Dbanner%26utm_campaign%3Dhomepage-jan12" rel="noopener" target="_blank"><img alt="Get it on Google Play" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-playstore_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-playstore_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-playstore_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-playstore.png 3x" width="160"/></a><a class="k-mr-2 k-mb-4 md:k-mb-0" href="https://appgallery.huawei.com/#/app/C102650235" rel="noopener" target="_blank"><img alt="Download on AppGallery" class="k-h-12 k-w-auto md:k-h-10" decoding="async" height="48" loading="lazy" src="https://static.kalibrr.com/public/kalibrr-app-link-huawei_3x.png" srcset="https://static.kalibrr.com/public/kalibrr-app-link-huawei_3x.png, https://static.kalibrr.com/public/kalibrr-app-link-huawei_2x.png 2x, https://static.kalibrr.com/public/kalibrr-app-link-huawei.png 3x" width="160"/></a></div>,
#  <div class="k-flex k-flex-col k-justify-between k-my-8 md:k-flex-row md:k-w-8/12 lg:k-w-6/12"><div class="k-mb-4"><h3 class="k-font-semibold k-text-primary-color">Job Seekers</h3><ul><li class="k-my-2"><a class="k-text-black" href="/signup">Sign Up</a></li><li class="k-my-2"><a class="k-text-black" href="/job-board">Job Board</a></li><li class="k-my-2"><a class="k-text-black" href="/job-category">Job Category</a></li><li class="k-my-2"><a class="k-text-black" href="/jobseeker-guide">Jobseeker Guide</a></li></ul></div><div class="k-mb-4"><h3 class="k-font-semibold k-text-primary-color">Employers</h3><ul><li class="k-my-2"><a class="k-text-black" href="/employers/">Start Hiring</a></li><li class="k-my-2"><a class="k-text-black" href="/sourcing">Kalibrr Sourcing</a></li><li class="k-my-2"><a class="k-text-black" href="/contactus">Kalibrr Partnership</a></li></ul></div><div class="k-mb-4"><h3 class="k-font-semibold k-text-primary-color">About Kalibrr</h3><ul><li class="k-my-2"><a class="k-text-black" href="/about">About</a></li><li class="k-my-2"><a class="k-text-black" href="/c/kalibrr-ph">Careers</a></li><li class="k-my-2"><a class="k-text-black" href="/blog">Blog</a></li></ul></div></div>,
#  <div class="k-mb-4"><h3 class="k-font-semibold k-text-primary-color">Job Seekers</h3><ul><li class="k-my-2"><a class="k-text-black" href="/signup">Sign Up</a></li><li class="k-my-2"><a class="k-text-black" href="/job-board">Job Board</a></li><li class="k-my-2"><a class="k-text-black" href="/job-category">Job Category</a></li><li class="k-my-2"><a class="k-text-black" href="/jobseeker-guide">Jobseeker Guide</a></li></ul></div>,
#  <div class="k-mb-4"><h3 class="k-font-semibold k-text-primary-color">Employers</h3><ul><li class="k-my-2"><a class="k-text-black" href="/employers/">Start Hiring</a></li><li class="k-my-2"><a class="k-text-black" href="/sourcing">Kalibrr Sourcing</a></li><li class="k-my-2"><a class="k-text-black" href="/contactus">Kalibrr Partnership</a></li></ul></div>,
#  <div class="k-mb-4"><h3 class="k-font-semibold k-text-primary-color">About Kalibrr</h3><ul><li class="k-my-2"><a class="k-text-black" href="/about">About</a></li><li class="k-my-2"><a class="k-text-black" href="/c/kalibrr-ph">Careers</a></li><li class="k-my-2"><a class="k-text-black" href="/blog">Blog</a></li></ul></div>,
#  <div class="k-flex k-flex-col k-text-caption k-justify-between k-text-gray-500 md:k-flex-row md:k-justify-start md:k-w-full"><p class="k-mb-4 md:k-mr-4">© <!-- -->2023<!-- --> Kalibrr Inc.</p><p><a class="k-text-gray-500" href="/terms">Terms of Use</a> | <a class="k-text-gray-500" href="/dsa">Data Sharing Policy</a> | <a class="k-text-gray-500" href="/privacy">Privacy Policy</a></p></div>]

# %% [markdown]
# Finding row length.

# %%
row=soup.find_all('a',attrs={'class':'k-text-primary-color'})
print(len(row))
jumlahbaris=(len(row))
# Out:
# 18

# %%
... = table.find_all(...)
row_length = len(...)

# %%
jumlahbaris=15

# %% [markdown]
# Do the scrapping process here (please change this markdown with your explanation)

# %%
temp = [] #initiating a tuple

for i in range(1, jumlahbaris):
    #get data
    posisi = soup.find_all('a',attrs={'class':'k-text-primary-color'})[i].text
    lokasi = soup.find_all('a',attrs={'class':'k-text-subdued k-block'})[i].text
    perusahaan = soup.find_all('a',attrs={'class':'k-text-subdued'})[i].text
    post_submit = soup.find_all('span',attrs={'class':'k-block k-mb-1'})[i].text
    
    temp.append((posisi,lokasi,perusahaan,post_submit))
    
temp
# Out:
# [('Data Engineer',
#   'Jakarta Selatan, Indonesia',
#   'PT Berlian Sistem Informasi',
#   'Posted 12 days ago • Apply before 25 Apr'),
#  ('IT Data Center  Monitoring',
#   'Jakarta, Indonesia',
#   'East Jakarta, Indonesia',
#   'Posted 13 days ago • Apply before 29 Oct'),
#  ('Big Data Engineer (DM)',
#   'West Jakarta, Indonesia',
#   '',
#   'Posted 12 days ago • Apply before 17 Dec'),
#  ('Full Stack Developer (ReactJS & Golang)',
#   'Jakarta, Indonesia',
#   'VLink Inc',
#   'Posted 4 days ago • Apply before 19 Sep'),
#  ('Data Engineer',
#   'Jakarta Selatan, Indonesia',
#   'Jakarta Selatan, Indonesia',
#   'Posted 10 days ago • Apply before 30 Oct'),
#  ('Digital Marketing Specialist',
#   'Tangerang Kota, Indonesia',
#   '',
#   'Posted 9 days ago • Apply before 30 Sep'),
#  ('Data Engineer',
#   'Jakarta Selatan, Indonesia',
#   'PGI Data',
#   'Posted 16 days ago • Apply before 16 Oct'),
#  ('IT Asset Management Officer',
#   'East Jakarta, Indonesia',
#   'Jakarta, Indonesia',
#   'Posted a month ago • Apply before 23 Nov'),
#  ('DevOps and Data Engineer',
#   'Tangerang Selatan, Indonesia',
#   '',
#   'Posted a month ago • Apply before 5 Nov'),
#  ('Data Engineering & Insight Lead (Head of Data)',
#   'Central Jakarta City, Indonesia',
#   'PT. Indocyber Global Technology',
#   'Posted 19 days ago • Apply before 13 Oct'),
#  ('Data Engineer',
#   'Jakarta Selatan, Indonesia',
#   'West Jakarta, Indonesia',
#   'Posted 2 months ago • Apply before 29 Sep'),
#  ('Client Success Associate',
#   'South Jakarta, Indonesia',
#   '',
#   'Posted 2 months ago • Apply before 22 Jun'),
#  ('Sr Business Development (B2B Corporate Sales)',
#   'Jakarta Selatan, Indonesia',
#   'PGI Data',
#   'Posted 2 months ago • Apply before 3 Sep'),
#  ('Data Scientist',
#   'South Jakarta, Indonesia',
#   'Jakarta, Indonesia',
#   'Posted 6 days ago • Apply before 30 Oct')]

# %%
# coba pindah halaman

temp = [] #initiating a tuple

for i in range(1, jumlahbaris):
    #get data
    posisi = soup.find_all('a',attrs={'class':'k-text-primary-color'})[i].text
    lokasi = soup.find_all('a',attrs={'class':'k-text-subdued k-block'})[i].text
    perusahaan = soup.find_all('a',attrs={'class':'k-text-subdued'})[i].text
    post_submit = soup.find_all('span',attrs={'class':'k-block k-mb-1'})[i].text
    
    temp.append((posisi,lokasi,perusahaan,post_submit))
    if i==1:
        try:
            lanjut = soup.find('a', class_='').get('href') 
            driver.get('https://www.jobstreet.co.id'+lanjut)
        except:
            break    



temp

# %% [markdown]
# ## Creating data frame & Data wrangling

# %% [markdown]
# Put the array into dataframe

# %%
import pandas as pd

df = pd.DataFrame(temp,columns=('posisi','lokasi','perusahaan','post_submit'))
df.head()
# Out:
#                                     posisi                      lokasi
# 0                            Data Engineer  Jakarta Selatan, Indonesia  \
# 1               IT Data Center  Monitoring          Jakarta, Indonesia
# 2                   Big Data Engineer (DM)     West Jakarta, Indonesia
# 3  Full Stack Developer (ReactJS & Golang)          Jakarta, Indonesia
# 4                            Data Engineer  Jakarta Selatan, Indonesia
#
#                     perusahaan                               post_submit
# 0  PT Berlian Sistem Informasi  Posted 12 days ago • Apply before 25 Apr
# 1      East Jakarta, Indonesia  Posted 13 days ago • Apply before 29 Oct
# 2                               Posted 12 days ago • Apply before 17 Dec
# 3                    VLink Inc   Posted 4 days ago • Apply before 19 Sep
# 4   Jakarta Selatan, Indonesia  Posted 10 days ago • Apply before 30 Oct

# %% [markdown]
# Do the data cleaning here (please change this markdown with your explanation of what you do for data wrangling)

# %% [markdown]
# Data visualisation (please change this markdown with your explanation of what you do for data wrangling)

# %% [markdown]
# ### Implementing your webscrapping to the flask dashboard
#
# - Copy paste all of your web scrapping process to the desired position on the `app.py`
# - Changing the title of the dasboard at `index.html`

# %% [markdown]
# ## Finishing This Notebook with Your Analysis and Conclusion
#
# First you can do start with making the data visualisation.

# %% [markdown]
# (Put your analysis and conclusion here.)

# %% [markdown]
# ### Implement it at the webapps
#
# - You can create additional analysis from the data.
# - Implement it to the dashboard with at `app.py` dan `index.html`.
